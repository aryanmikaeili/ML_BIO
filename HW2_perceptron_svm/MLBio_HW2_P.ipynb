# %% [markdown]
# # Machine Learning in Bioinformatics

# %% [markdown]
# # Homework 2:
#  !!! If you don't fill these fields, your homework does not count !!!<by/>
#  #### first name and last name : Aryan Mikaeili
#  #### student number : 95105895

# %% [markdown]
# You can run cells by hitting `Shift` + `Enter` or `ctrl` + `Enter`. <br/>
# We highly recommend you to read each line of code carefully and try to understand what it exactly does. <br/>
# Just alter the parts that is between green comments and specified for you. Please do not change other parts.

# %%
# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
# %matplotlib inline
plt.rcParams['figure.figsize'] = (30.0, 10.0)

# %% [markdown]
# # Problem 1. soft margin SVM
# ### about the Data:<br/>
# The purpose of this project is to classify tumors into malignant or benign. The following dataset is constructed based on images of tumors. Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.
# For more details about the features of this dataset you can visit this link:
# https://scikit-learn.org/stable/datasets/index.html#breast-cancer-dataset<br/>
# This dataset contains 30 features and 1 label that is called target. We should find a proper hyperplane that separates malignant and benign samples.
# The original dataset labels is 0 and 1 and in the following code boxes we change it to -1 and 1.

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(np.c_[cancer["data"], cancer["target"]], columns = np.append(cancer["feature_names"],["target"]))
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890     0.0
# 1          0.2750                  0.08902     0.0
# 2          0.3613                  0.08758     0.0
# 3          0.6638                  0.17300     0.0
# 4          0.2364                  0.07678     0.0
#
# [5 rows x 31 columns]

# %%
cancer.target = np.where(cancer.target==0, -1, cancer.target) 
X_train ,X_test ,X_val ,y_train ,y_test ,y_val = None ,None ,None ,None ,None ,None
################################################################################
# TODO: using train_test_split package, split your data into 3 numpy array     #
# called X_train, X_test, and X_val and also split the corresponding labels as #
# y_train, y_test, and y_val. After spliting, the ratio of your data should be # 
# approximately like this:                                                     #
#  Train : 72%     test : 20%       validation : 8%                            #
################################################################################

#write your code here
X = cancer["data"]
Y = cancer["target"]
Y[Y == 0] = -1

X_train, X_test, y_train, y_test = train_test_split(X, Y, shuffle=True, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
print((X_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_val.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_val.shape[0]/cancer.data.shape[0]) * 100, "%")
# Out:
# 71.8804920913884 %
# 71.8804920913884 %
# 20.035149384885763 %
# 20.035149384885763 %
# 8.084358523725834 %
# 8.084358523725834 %

# %% [markdown]
# ### soft margin SVM optimization:<br/>
# We add 1 at the beginning of each Xs data (X_train, X_val , ...) and then the bias will be calculated implicitly.
# Then you should minimize the following SVM loss function (using gradient descent) with changing parameters of model.<br>
# In this notation:
# \begin{equation}
# x_i , y_i
# \end{equation}
# refers to feature vector of the sample and the label of our training data<br>
# and this is SVM loss function:
#
# \begin{equation}
# \large
# J(W) = \frac{1}{N} \sum_{i=1}^{N}{L^{(i)}} + \frac{\lambda}{2} ||W||^2\\
# \large
# L^{(i)} ={max(0, 1 - y_i(w^{T}x_i)})
# \;\\
# \end{equation}

# %%
# >>>>>WARNING: RUN THIS CELL ONLY ONCE!<<<<<

# adding 1s to the end of feature vectors to be multiplied by bias term of weights
X_val = np.insert(X_val, 0, 1, axis=1)
X_train = np.insert(X_train, 0, 1, axis=1)
X_test = np.insert(X_test, 0, 1, axis=1)
print(X_train.shape)  
print(X_val.shape)  
print(X_test.shape)
# Out:
# (409, 31)
# (46, 31)
# (114, 31)

# %% [markdown]
# Complete the following functions in SVM class. In the part that you should compute loss function of this class, you are not allowed to use "for" loop.

# %%
class SVM:
    def __init__(self, n_features: int, std: float):
        """
        n_features: number of features in (or the dimension of) each instance
        std: standard deviation used in the initialization of the weights of svm
        """
        self.n_features = n_features
        ################################################################################
        # TODO: Initialize the weights of svm using random normal distribution with    #
        # standard deviation equals to std.                                            #
        ################################################################################

        #write your code here
        self.weights = np.random.normal(0, std, self.n_features)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        """
        X: training instances as a 2d-array with shape (num_train, n_features)
        y: labels corresponsing to the given training instances as a 1d-array with shape (num_train,)
        reg_coeff: L2-regularization coefficient
        """
        loss = 0.0
        
        #################################################################################
        # TODO: Compute the hinge loss specified in the notebook and save it in the loss#                                                   # loss variable.                                                               #
        # NOTE: YOU ARE NOT ALLOWED TO USE FOR LOOPS!                                   #
        # Don't forget L2-regularization term in your implementation!                   #
        #################################################################################
        
        #write your code here
        N = len(X)
        loss = np.sum((1 - np.matmul(X, self.weights) * y)[np.where((1 - np.matmul(X, self.weights) * y) > 0)]) / N
        loss += ((reg_coeff / 2) * np.dot(self.weights, self.weights))
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return loss
        
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float , reg_coeff: float):
        """
        Updates the weights of the svm using the gradient of computed loss with respect to the weights. 
        learning_rate: learning rate that will be used in gradient descent to update the weights
        """
        ################################################################################
        # TODO: Compute the gradient of loss computed above w.r.t the svm weights.     #
        # and then update self.w with the computed gradient.                           #
        # (don't forget learning rate and reg_coeff in update rule)                    #
        # Don't forget L2-regularization term in your implementation!                  #
        ################################################################################
        
        #write your code here
        N = len(X)
        gradient = ((-1 * np.sum(((X.T * y).T)[np.where((1 - np.matmul(X, self.weights) * y) > 0)], axis=0)) / N) + reg_coeff * self.weights
        self.weights -= learning_rate * gradient

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
    def predict(self, X):
        """
        X: Numpy 2d-array of instances
        """
        y_pred = None
        ################################################################################
        # TODO: predict the labels for the instances in X and save them in y_pred.     #                                      #
        ################################################################################

        #write your code here
        y_pred = []
        N = len(X)
        for i in range(N):
            if np.dot(X[i], self.weights) >= 0:
                y_pred.append(1)
            else:
                y_pred.append(-1)

        y_pred = np.array(y_pred)


        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return y_pred

# %% [markdown]
# This cell contains your hyper parameters:

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8

# %% [markdown]
# In this cell using your SVM class, we want to train our model for cancer data:<br/>
# In every iteration you should see your training loss decrease.

# %%
from sklearn.metrics import accuracy_score
model = SVM(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.043957, val acc 60.87%
# iteration 100, loss 1.008539, val acc 60.87%
# iteration 200, loss 0.973122, val acc 39.13%
# iteration 300, loss 0.943942, val acc 39.13%
# iteration 400, loss 0.933751, val acc 39.13%
# iteration 500, loss 0.930210, val acc 39.13%
# iteration 600, loss 0.928268, val acc 39.13%
# iteration 700, loss 0.926605, val acc 39.13%
# iteration 800, loss 0.924943, val acc 39.13%
# iteration 900, loss 0.923280, val acc 39.13%
# iteration 1000, loss 0.921619, val acc 39.13%
# iteration 1100, loss 0.919961, val acc 39.13%
# iteration 1200, loss 0.918315, val acc 39.13%
# iteration 1300, loss 0.916672, val acc 39.13%
# iteration 1400, loss 0.915042, val acc 39.13%
# iteration 1500, loss 0.913440, val acc 39.13%
# iteration 1600, loss 0.911846, val acc 39.13%
# iteration 1700, loss 0.910259, val acc 39.13%
# iteration 1800, loss 0.908674, val acc 39.13%
# iteration 1900, loss 0.907090, val acc 39.13%
# iteration 2000, loss 0.905505, val acc 39.13%
# iteration 2100, loss 0.903921, val acc 39.13%
# iteration 2200, loss 0.902363, val acc 39.13%
# iteration 2300, loss 0.900811, val acc 39.13%
# iteration 2400, loss 0.899280, val acc 39.13%
# iteration 2500, loss 0.897758, val acc 39.13%
# iteration 2600, loss 0.896241, val acc 39.13%
# iteration 2700, loss 0.894726, val acc 39.13%
# iteration 2800, loss 0.893210, val acc 39.13%
# iteration 2900, loss 0.891701, val acc 39.13%
# iteration 3000, loss 0.890238, val acc 39.13%
# iteration 3100, loss 0.888784, val acc 39.13%
# iteration 3200, loss 0.887331, val acc 39.13%
# iteration 3300, loss 0.885899, val acc 39.13%
# iteration 3400, loss 0.884467, val acc 39.13%
# iteration 3500, loss 0.883066, val acc 39.13%
# iteration 3600, loss 0.881695, val acc 39.13%
# iteration 3700, loss 0.880324, val acc 39.13%
# iteration 3800, loss 0.878962, val acc 39.13%
# iteration 3900, loss 0.877602, val acc 39.13%
# iteration 4000, loss 0.876243, val acc 39.13%
# iteration 4100, loss 0.874887, val acc 39.13%
# iteration 4200, loss 0.873531, val acc 39.13%
# iteration 4300, loss 0.872176, val acc 39.13%
# iteration 4400, loss 0.870820, val acc 39.13%
# iteration 4500, loss 0.869465, val acc 39.13%
# iteration 10500, loss 0.789642, val acc 69.57%
# iteration 10600, loss 0.788322, val acc 69.57%
# iteration 10700, loss 0.787003, val acc 69.57%
# iteration 10800, loss 0.785684, val acc 73.91%
# iteration 10900, loss 0.784364, val acc 73.91%
# iteration 11000, loss 0.783045, val acc 76.09%
# iteration 11100, loss 0.781726, val acc 76.09%
# iteration 11200, loss 0.780407, val acc 78.26%
# iteration 11300, loss 0.779088, val acc 78.26%
# iteration 11400, loss 0.777769, val acc 80.43%
# iteration 11500, loss 0.776450, val acc 82.61%
# iteration 11600, loss 0.775131, val acc 82.61%
# iteration 11700, loss 0.773813, val acc 82.61%
# iteration 11800, loss 0.772494, val acc 82.61%
# iteration 11900, loss 0.771175, val acc 82.61%
# iteration 12000, loss 0.769856, val acc 80.43%
# iteration 12100, loss 0.768538, val acc 82.61%
# iteration 12200, loss 0.767219, val acc 84.78%
# iteration 12300, loss 0.765901, val acc 84.78%
# iteration 12400, loss 0.764582, val acc 84.78%
# iteration 12500, loss 0.763264, val acc 84.78%
# iteration 12600, loss 0.761946, val acc 84.78%
# iteration 12700, loss 0.760628, val acc 84.78%
# iteration 12800, loss 0.759309, val acc 84.78%
# iteration 12900, loss 0.757991, val acc 84.78%
# iteration 13000, loss 0.756673, val acc 84.78%
# iteration 13100, loss 0.755355, val acc 86.96%
# iteration 13200, loss 0.754037, val acc 86.96%
# iteration 13300, loss 0.752719, val acc 86.96%
# iteration 13400, loss 0.751401, val acc 86.96%
# iteration 13500, loss 0.750083, val acc 89.13%
# iteration 13600, loss 0.748766, val acc 89.13%
# iteration 13700, loss 0.747448, val acc 89.13%
# iteration 13800, loss 0.746130, val acc 89.13%
# iteration 13900, loss 0.744813, val acc 89.13%
# iteration 14000, loss 0.743495, val acc 86.96%
# iteration 14100, loss 0.742177, val acc 86.96%
# iteration 14200, loss 0.740860, val acc 86.96%
# iteration 14300, loss 0.739543, val acc 86.96%
# iteration 14400, loss 0.738225, val acc 86.96%
# iteration 14500, loss 0.736908, val acc 86.96%
# iteration 14600, loss 0.735591, val acc 89.13%
# iteration 14700, loss 0.734273, val acc 86.96%
# iteration 14800, loss 0.732956, val acc 86.96%
# iteration 14900, loss 0.731648, val acc 89.13%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #
# using loss_loss_history and loss_val_history                                     #
####################################################################################

#write your code here

plt.plot([i for i in range(num_iters)], loss_history)
plt.plot([i for i in range(num_iters)], loss_val_history)
plt.show()
####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 1:
# With changing your hyper parameters, find a configuration of hyper parameters that cause your loss to increase after each iteration and then report that configuration in the next cell. Explain why our loss increases?
# Write your answer in ""

# %% [markdown]
# std = "0.0001" <br>
# num_iters = "15000"<br>
# reg_coeff = "20"<br>
# learning_rate = "5 $\times$ 1e-6"<br>

# %% [markdown]
# ### Question 2:
# In this cell please explain the reason of this event<br>
# Answer: If the learning rate is too big, the loss will miss the optimum point and probably will oscillate around the optimum point

# %%
val_preds =  model.predict(X_test)
###########################################################################################
# TODO: find the Confusion Matrix between val_preds and real labels (y_test) for test data#
# then report the accuracy of the model.                                                  #
# you are not allowed to use any premade function for accuracy and confusion matrix       #
###########################################################################################

#write your code here
def confusion_matrix(prediction, labels):
    true_preds = np.array(prediction)[np.where(prediction == labels)]
    one_predictions = prediction[prediction == 1]
    TP = len(true_preds[true_preds == 1])
    TN = len(true_preds[true_preds == -1])
    FP = len(one_predictions) - TP
    FN = len(labels) - len(one_predictions) - TN

    return [[TP, FP], [FN, TN]]

def accuracy(predictions, labels):
    number_of_true =  np.sum(predictions == labels)
    return (number_of_true / len(predictions)) * 100


print("test accuracy: " + str(accuracy(val_preds, y_test)))
print(confusion_matrix(y_preds, y_test))

###########################################################################################
#                                END OF YOUR EXPLANATION                                  #
###########################################################################################
# Out:
# test accuracy: 88.59649122807018
# [[66, 5], [7, 36]]

# %% [markdown]
# In the next part, we sample from training data with certain size (batch size) instead of using all the training data in each iteration, and train our model on batch data:

# %%
std = 0.0001
batch_size = 200
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8
model = SVM(n_features=X_train.shape[1], std= std )

# %%
loss_history = []
loss_val_history = []
for it in range(num_iters):
    X_batch = None
    y_batch = None
    ################################################################################
    # TODO: Sample batch_size elements from the training data and their            #
    # corresponding labels to use in this round of gradient descent.               #
    # Store the data in X_batch and their corresponding labels in                  #
    # y_batch; after sampling X_batch should have shape (batch_size, n_features)   #
    # and y_batch should have shape (batch_size,)                                  #
    #                                                                              #
    # Hint: Use np.random.choice to generate indices. Sampling with                #
    # replacement is faster than sampling without replacement.                     #
    ################################################################################

    #write your code here
    index = np.random.choice([i for i in range(len(X_train))], batch_size)
    X_batch = X_train[index]
    y_batch = y_train[index]


    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################
    loss = model.loss(X_batch, y_batch, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_batch, y_batch, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 0.988506, val acc 39.13%
# iteration 100, loss 0.986346, val acc 39.13%
# iteration 200, loss 0.938620, val acc 39.13%
# iteration 300, loss 0.896629, val acc 39.13%
# iteration 400, loss 0.930130, val acc 39.13%
# iteration 500, loss 0.920224, val acc 39.13%
# iteration 600, loss 0.877162, val acc 39.13%
# iteration 700, loss 0.892303, val acc 39.13%
# iteration 800, loss 0.915419, val acc 39.13%
# iteration 900, loss 0.898355, val acc 39.13%
# iteration 1000, loss 0.861523, val acc 39.13%
# iteration 1100, loss 0.905458, val acc 39.13%
# iteration 1200, loss 0.901023, val acc 39.13%
# iteration 1300, loss 0.919624, val acc 39.13%
# iteration 1400, loss 0.980523, val acc 39.13%
# iteration 1500, loss 0.914966, val acc 39.13%
# iteration 1600, loss 0.891489, val acc 39.13%
# iteration 1700, loss 0.859302, val acc 39.13%
# iteration 1800, loss 0.927969, val acc 39.13%
# iteration 1900, loss 0.896211, val acc 39.13%
# iteration 2000, loss 0.909008, val acc 39.13%
# iteration 2100, loss 0.879412, val acc 39.13%
# iteration 2200, loss 0.936256, val acc 39.13%
# iteration 2300, loss 0.904990, val acc 39.13%
# iteration 2400, loss 0.928280, val acc 39.13%
# iteration 2500, loss 0.856799, val acc 39.13%
# iteration 2600, loss 0.894069, val acc 39.13%
# iteration 2700, loss 0.847004, val acc 39.13%
# iteration 2800, loss 0.872241, val acc 39.13%
# iteration 2900, loss 0.820733, val acc 39.13%
# iteration 3000, loss 0.842031, val acc 39.13%
# iteration 3100, loss 0.878081, val acc 39.13%
# iteration 3200, loss 0.880838, val acc 39.13%
# iteration 3300, loss 0.851949, val acc 39.13%
# iteration 3400, loss 0.899299, val acc 39.13%
# iteration 3500, loss 0.941722, val acc 39.13%
# iteration 3600, loss 0.881488, val acc 39.13%
# iteration 3700, loss 0.918980, val acc 39.13%
# iteration 3800, loss 0.879357, val acc 39.13%
# iteration 3900, loss 0.809226, val acc 39.13%
# iteration 4000, loss 0.876353, val acc 39.13%
# iteration 4100, loss 0.877666, val acc 39.13%
# iteration 4200, loss 0.831256, val acc 39.13%
# iteration 4300, loss 0.885831, val acc 39.13%
# iteration 4400, loss 0.880359, val acc 39.13%
# iteration 4500, loss 0.851612, val acc 39.13%
# iteration 4600, loss 0.857156, val acc 39.13%
# iteration 4700, loss 0.841547, val acc 39.13%
# iteration 4800, loss 0.847798, val acc 39.13%
# iteration 4900, loss 0.880930, val acc 39.13%
# iteration 5000, loss 0.916048, val acc 39.13%
# iteration 5100, loss 0.828118, val acc 39.13%
# iteration 5200, loss 0.878835, val acc 39.13%
# iteration 5300, loss 0.831324, val acc 39.13%
# iteration 5400, loss 0.779004, val acc 39.13%
# iteration 5500, loss 0.888335, val acc 39.13%
# iteration 5600, loss 0.786863, val acc 39.13%
# iteration 5700, loss 0.813165, val acc 39.13%
# iteration 5800, loss 0.842981, val acc 39.13%
# iteration 5900, loss 0.890462, val acc 39.13%
# iteration 6000, loss 0.853611, val acc 39.13%
# iteration 6100, loss 0.829687, val acc 41.30%
# iteration 6200, loss 0.839357, val acc 41.30%
# iteration 6300, loss 0.904810, val acc 41.30%
# iteration 6400, loss 0.817169, val acc 43.48%
# iteration 6500, loss 0.852077, val acc 43.48%
# iteration 6600, loss 0.816450, val acc 43.48%
# iteration 6700, loss 0.827153, val acc 43.48%
# iteration 6800, loss 0.852820, val acc 43.48%
# iteration 6900, loss 0.822627, val acc 43.48%
# iteration 7000, loss 0.867320, val acc 41.30%
# iteration 7100, loss 0.833756, val acc 41.30%
# iteration 7200, loss 0.808360, val acc 41.30%
# iteration 13200, loss 0.759574, val acc 89.13%
# iteration 13300, loss 0.781613, val acc 89.13%
# iteration 13400, loss 0.753445, val acc 89.13%
# iteration 13500, loss 0.765976, val acc 89.13%
# iteration 13600, loss 0.776183, val acc 86.96%
# iteration 13700, loss 0.742795, val acc 86.96%
# iteration 13800, loss 0.688695, val acc 86.96%
# iteration 13900, loss 0.767902, val acc 86.96%
# iteration 14000, loss 0.726837, val acc 89.13%
# iteration 14100, loss 0.735384, val acc 86.96%
# iteration 14200, loss 0.713259, val acc 86.96%
# iteration 14300, loss 0.718286, val acc 89.13%
# iteration 14400, loss 0.733034, val acc 89.13%
# iteration 14500, loss 0.761653, val acc 86.96%
# iteration 14600, loss 0.749667, val acc 89.13%
# iteration 14700, loss 0.730887, val acc 89.13%
# iteration 14800, loss 0.681429, val acc 89.13%
# iteration 14900, loss 0.739042, val acc 89.13%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #

####################################################################################

#write your code here
plt.plot([i for i in range(num_iters)], loss_history)
plt.plot([i for i in range(num_iters)], loss_val_history)
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 3:
# Explain why we see fluctuation in this plot?<br>
# Answer: because in each step we are not calculating the exact gradient and by choosing a subset of the training data, we are approximating the gradient function. therefore, in the course of training we might see fluctuations in each step and with decreasing the batch_size,the flucttation will naturally increase.

# %% [markdown]
# # Problem 2. Perceptron

# %% [markdown]
# By now, you should know how to use and how to implement SVM from scratch.
# In fact, for perceptron we can use premade functions as below:

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
val_preds = clf.predict(X_test)
print(confusion_matrix(y_test,val_preds,[1,-1]))
print('test acc %.2f%%' % (accuracy_score(y_test,val_preds) * 100))
# Out:
# [[73  0]
#  [31 10]]
# test acc 72.81%

# %% [markdown]
# ### Question 4:
# It is time for you to write your own code instead of completing some parts of a premade code.<br>
# So you can not use any premade functions like the previous cell.
# Write your code in the end of this .ipynb file <br>
# You should make your model and use that to build these outputs:<br>
# 1- Report loss of training and accuracy of validation data on each epoch of training process.<br>
# 2- You are allowed to use any normalization approach if need be.<br>
# 3- Plot your training and validation loss vs number of iterations in one plot.<br>
# 4- Finally print your confusion matrix and accuracy for your testing set.<br>
# With changing your hyperparameters try to get a good and reasonable accuracy and confusion matrix on testing set (similar to the accuracy when we used the package).

# %%
class perceptron:
    def __init__(self, n_features: int, std: float):

        self.n_features = n_features
        self.weights = np.random.normal(0, std, self.n_features)

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):


        N = len(X)
        loss = np.sum((-1 * np.matmul(X, self.weights) * y)[np.where((np.matmul(X, self.weights) * y) < 0)]) / N
        loss += ((reg_coeff / 2) * np.dot(self.weights, self.weights))

        return loss

    def update_weights(self, X: np.ndarray, y: np.ndarray, learning_rate: float, reg_coeff: float):

        N = len(X)
        gradient = ((-1 * np.sum(((X.T * y).T)[np.where((-1 * np.matmul(X, self.weights) * y) > 0)], axis=0)) / N) + reg_coeff * self.weights
        self.weights -= learning_rate * gradient

    def predict(self, X):
        y_pred = []
        N = len(X)
        for i in range(N):
            if np.dot(X[i], self.weights) >= 0:
                y_pred.append(1)
            else:
                y_pred.append(-1)

        y_pred = np.array(y_pred)
        return y_pred

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate = 5 * 1e-9

model = perceptron(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 0.007453, val acc 60.87%
# iteration 100, loss 0.001099, val acc 69.57%
# iteration 200, loss 0.001058, val acc 69.57%
# iteration 300, loss 0.001019, val acc 69.57%
# iteration 400, loss 0.000982, val acc 69.57%
# iteration 500, loss 0.000946, val acc 73.91%
# iteration 600, loss 0.000912, val acc 73.91%
# iteration 700, loss 0.000879, val acc 73.91%
# iteration 800, loss 0.000845, val acc 73.91%
# iteration 900, loss 0.000813, val acc 73.91%
# iteration 1000, loss 0.000781, val acc 73.91%
# iteration 1100, loss 0.000749, val acc 73.91%
# iteration 1200, loss 0.000719, val acc 73.91%
# iteration 1300, loss 0.000688, val acc 73.91%
# iteration 1400, loss 0.000658, val acc 73.91%
# iteration 1500, loss 0.000630, val acc 73.91%
# iteration 1600, loss 0.000604, val acc 73.91%
# iteration 1700, loss 0.000578, val acc 76.09%
# iteration 1800, loss 0.000553, val acc 78.26%
# iteration 1900, loss 0.000531, val acc 78.26%
# iteration 2000, loss 0.000510, val acc 78.26%
# iteration 2100, loss 0.000490, val acc 78.26%
# iteration 2200, loss 0.000472, val acc 78.26%
# iteration 2300, loss 0.000455, val acc 78.26%
# iteration 2400, loss 0.000440, val acc 78.26%
# iteration 2500, loss 0.000425, val acc 78.26%
# iteration 2600, loss 0.000410, val acc 78.26%
# iteration 2700, loss 0.000396, val acc 78.26%
# iteration 2800, loss 0.000383, val acc 78.26%
# iteration 2900, loss 0.000370, val acc 78.26%
# iteration 3000, loss 0.000358, val acc 78.26%
# iteration 3100, loss 0.000347, val acc 78.26%
# iteration 3200, loss 0.000336, val acc 76.09%
# iteration 3300, loss 0.000325, val acc 76.09%
# iteration 3400, loss 0.000314, val acc 76.09%
# iteration 3500, loss 0.000304, val acc 76.09%
# iteration 3600, loss 0.000294, val acc 76.09%
# iteration 3700, loss 0.000285, val acc 76.09%
# iteration 3800, loss 0.000275, val acc 76.09%
